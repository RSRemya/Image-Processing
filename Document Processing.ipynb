# %%
#!pip install opencv-python

# %%
import cv2
import matplotlib.pyplot as plt#for displaying the image

# %%
image=cv2.imread("image1.jpg")
plt.imshow(image)

# %%
thresh, thresh4_image=cv2.threshold(doc_image, 150,255, cv2.THRESH_BINARY)
plt.imshow(thresh4_image)

# %%
doc2_image=cv2.imread("image2.jpg")
plt.imshow(doc2_image)

# %%
doc2_gray_image = cv2.cvtColor(doc2_image, cv2.COLOR_BGR2GRAY)
thresh, thresh6_image=cv2.threshold(doc2_image, 200,220, cv2.THRESH_BINARY)
plt.imshow(thresh6_image)
